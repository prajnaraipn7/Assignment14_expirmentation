# %%
import numpy as np
import tensorflow as tf
import os
from keras import regularizers
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D,AveragePooling2D
from keras.layers import Activation, Flatten, Dense, Dropout,SpatialDropout2D
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
import cv2
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D,ZeroPadding2D,AveragePooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.layers import Input,add
from keras.models import Model
from keras.layers import concatenate 
from keras.layers import GlobalAveragePooling2D
# Out:
# Using TensorFlow backend.

# %%
#loading dataset
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 9s 0us/step

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
def get_cutout_eraser_and_random_crop(p=0.5,s_l=0.05,s_h=0.3,r_1=0.3,r_2=1/0.3,max_erasers_per_image=1,pixel_level=True,random_crop_size=(32,32),padding_pixels=4):
  
  assert max_erasers_per_image>=1 
  def eraser(input_img):
        v_l = np.min(input_img)
        v_h = np.max(input_img)
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img
        mx = np.random.randint(1,max_erasers_per_image+1)
        for i in range(mx):
          while True:
              s = np.random.uniform(s_l, s_h) * img_h * img_w
              r = np.random.uniform(r_1, r_2)
              w = int(np.sqrt(s / r))
              h = int(np.sqrt(s * r))
              left = np.random.randint(0, img_w)
              top = np.random.randint(0, img_h)

              if left + w <= img_w and top + h <= img_h:
                  break

          if pixel_level:
              c = np.random.uniform(v_l, v_h, (h, w, img_c))
          else:
              c = np.random.uniform(v_l, v_h)

          input_img[top:top + h, left:left + w, :] = c
        return input_img

    
  def random_crop(input_image):
    assert input_image.shape[2]==3

    #pad for 4 pixels
    img = cv2.copyMakeBorder(input_image,padding_pixels,padding_pixels,padding_pixels,padding_pixels,cv2.BORDER_REPLICATE)
    height , width =img.shape[0],img.shape[1]
    dy,dx = random_crop_size
    x = np.random.randint(0,width - dx + 1)
    y = np.random.randint(0,height - dy + 1)
    return img[y:(y+dy),x:(x+dx),:]

  def preprocess_image(input_image):
    return eraser(random_crop(input_image))
  
  return preprocess_image

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint

datagen = ImageDataGenerator(horizontal_flip=0.5,preprocessing_function=get_cutout_eraser_and_random_crop())
test_datagen = ImageDataGenerator(horizontal_flip=True,vertical_flip=True)
#test_datagen.fit(train_features)

# %%
datagen.mean = np.array([0.4914, 0.4822, 0.4465], dtype=np.float32).reshape((1,1,3)) # ordering: [R, G, B]
datagen.std = np.array([0.2023, 0.1994, 0.2010], dtype=np.float32).reshape((1,1,3)) # ordering: [R, G, B

# %% [markdown]
# #Resnet Model Creation

# %%
def ResNetBlock(input_layer, channels,stride=1):
  
  bn_1 = BatchNormalization()(input_layer)
  activation_layer_b1 = Activation('relu')(bn_1)
  block_layer_1 = Convolution2D(channels, (3,3), padding='same',strides=stride)(activation_layer_b1)
  
  bn_2 = BatchNormalization()(block_layer_1)
  activation_layer_b2 = Activation('relu')(bn_2) 
  block_layer_2 = Convolution2D(channels, (3,3), padding='same')(activation_layer_b2)
   
  
  return block_layer_2

# %%
from keras.layers import Input, add, GlobalAveragePooling2D, Dense
from keras.models import Model

inputs =Input(shape=(32, 32, 3))

x1 = Convolution2D(32, (3, 3),padding='same')(inputs)   #32x32 
activation_x1 = Activation('relu')(x1)
bn1 = BatchNormalization()(activation_x1)

# x2 = Convolution2D(64, (3, 3),padding='same')(bn1)   #32x32 
# activation_x2 = Activation('relu')(x2)
# bn2 = BatchNormalization()(activation_x2)

# x3 = Convolution2D(64, (3, 3),padding='same')(bn2)   #32x32 
# activation_x3 = Activation('relu')(x3)
# bn3 = BatchNormalization()(activation_x3)


##block 1

blk1 = ResNetBlock(bn1,32)  ##32x32
z1 = add([blk1,bn1])

blk1_c = ResNetBlock(z1,32)
z1_c = add([blk1_c,z1])

drp1 = SpatialDropout2D(0.15)(z1_c)

##block 2

blk2 = ResNetBlock(drp1,64,stride=2)
one_blk = Convolution2D(64, (1, 1), padding='same',strides=2)(drp1)
z2 = add([blk2,one_blk])

blk2_c = ResNetBlock(z2,64)
z2_c = add([blk2_c,z2])

drp2 = SpatialDropout2D(0.15)(z2_c)

##block3

blk3 = ResNetBlock(drp2,128)
one_blk_1 = Convolution2D(128, (1, 1), padding='same')(drp2)
z3 = add([blk3,one_blk_1])

blk3_c = ResNetBlock(z3,128)
z3_c = add([blk3_c,z3])

drp3 = SpatialDropout2D(0.15)(z3_c)
##block4

blk4 = ResNetBlock(drp3,256,stride=2)
one_blk_2 = Convolution2D(256, (1, 1), padding='same',strides=2)(drp3)
z4 = add([blk4,one_blk_2])

blk4_c = ResNetBlock(z4,256)
z4_c = add([blk4_c,z4])


avg_pool_layer = GlobalAveragePooling2D()(z4_c)

#flatten_layer = Flatten()(avg_pool_layer)

fc_layer = Dense(10, activation='softmax')(avg_pool_layer)


model = Model(inputs=inputs, outputs= fc_layer)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0805 06:31:59.316717 140413016409984 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0805 06:31:59.353102 140413016409984 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0805 06:31:59.361452 140413016409984 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0805 06:31:59.400032 140413016409984 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0805 06:31:59.401047 140413016409984 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0805 06:32:02.033908 140413016409984 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0805 06:32:02.535103 140413016409984 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   9248        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   9248        activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 32)   0           conv2d_3[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 32)   128         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   9248        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   9248        activation_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 32)   0           conv2d_5[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_1 (SpatialDro (None, 32, 32, 32)   0           add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 32)   128         spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 64)   18496       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 64)   36928       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   2112        spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 64)   0           conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 64)   256         add_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   36928       activation_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 64)   0           conv2d_10[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_2 (SpatialDro (None, 16, 16, 64)   0           add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 64)   256         spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  73856       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  8320        spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 128)  0           conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 128)  512         add_5[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  147584      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 128)  147584      activation_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 128)  0           conv2d_15[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_3 (SpatialDro (None, 16, 16, 128)  0           add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 128)  512         spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    295168      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 256)    1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 256)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 256)    590080      activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    33024       spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 256)    0           conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 256)    1024        add_7[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 256)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    590080      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 256)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 256)    590080      activation_17[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 256)    0           conv2d_20[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 256)          0           add_8[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           2570        global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 2,802,122
# Trainable params: 2,798,666
# Non-trainable params: 3,456
# __________________________________________________________________________________________________

# %%
#from one_cycle_lr import LRFinder
from one_cycle_lr import LRFinder
num_samples= train_features.shape[0]
batch_size =512
num_epoch=50
max_lr= 0.1

# %% [markdown]
# #Best LR would be 0.01

# %%
from keras import optimizers

opt = optimizers.SGD()
model.compile(optimizer=opt , loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# W0805 06:33:07.682702 140413016409984 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
from one_cycle_lr import OneCycleLR

lr_manager = OneCycleLR(num_samples, num_epoch, batch_size, max_lr,
                        end_percentage=0.1, scale_percentage=None,
                        maximum_momentum=0.95, minimum_momentum=0.85)

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
filepath = "Resnet-13.hdf5"


checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')


# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 512),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 300, 
                                 validation_data = (test_features, test_labels), verbose=1,callbacks=[checkpoint,lr_manager])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=97, epochs=300)`
#   # Remove the CWD from sys.path while we load stuff.
# W0805 06:33:13.360838 140413016409984 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/300
# 97/97 [==============================] - 39s 399ms/step - loss: 2.0319 - acc: 0.2699 - val_loss: 2.7672 - val_acc: 0.2167
#
# Epoch 00001: val_acc improved from -inf to 0.21670, saving model to Resnet-13.hdf5
#  - lr: 0.01396 - momentum: 0.95
# Epoch 2/300
# 97/97 [==============================] - 33s 341ms/step - loss: 1.6488 - acc: 0.3902 - val_loss: 1.8829 - val_acc: 0.3657
#
# Epoch 00002: val_acc improved from 0.21670 to 0.36570, saving model to Resnet-13.hdf5
#  - lr: 0.01796 - momentum: 0.94
# Epoch 3/300
# 97/97 [==============================] - 33s 339ms/step - loss: 1.4812 - acc: 0.4538 - val_loss: 1.7311 - val_acc: 0.3938
#
# Epoch 00003: val_acc improved from 0.36570 to 0.39380, saving model to Resnet-13.hdf5
#  - lr: 0.02196 - momentum: 0.94
# Epoch 4/300
# 97/97 [==============================] - 32s 332ms/step - loss: 1.3638 - acc: 0.5023 - val_loss: 1.6855 - val_acc: 0.4539
#
# Epoch 00004: val_acc improved from 0.39380 to 0.45390, saving model to Resnet-13.hdf5
#  - lr: 0.02596 - momentum: 0.93
# Epoch 5/300
# 97/97 [==============================] - 32s 334ms/step - loss: 1.2477 - acc: 0.5467 - val_loss: 1.9147 - val_acc: 0.4656
#
# Epoch 00005: val_acc improved from 0.45390 to 0.46560, saving model to Resnet-13.hdf5
#  - lr: 0.02996 - momentum: 0.93
# Epoch 6/300
# 97/97 [==============================] - 32s 335ms/step - loss: 1.1629 - acc: 0.5786 - val_loss: 1.4893 - val_acc: 0.5075
#
# Epoch 00006: val_acc improved from 0.46560 to 0.50750, saving model to Resnet-13.hdf5
#  - lr: 0.03396 - momentum: 0.92
# Epoch 7/300
# 97/97 [==============================] - 32s 335ms/step - loss: 1.0929 - acc: 0.6045 - val_loss: 1.4676 - val_acc: 0.5108
#
# Epoch 00007: val_acc improved from 0.50750 to 0.51080, saving model to Resnet-13.hdf5
#  - lr: 0.03797 - momentum: 0.92
# Epoch 8/300
# 97/97 [==============================] - 33s 335ms/step - loss: 1.0375 - acc: 0.6277 - val_loss: 1.2044 - val_acc: 0.5955
#
# Epoch 00008: val_acc improved from 0.51080 to 0.59550, saving model to Resnet-13.hdf5
#  - lr: 0.04197 - momentum: 0.91
# Epoch 9/300
# 97/97 [==============================] - 33s 336ms/step - loss: 0.9874 - acc: 0.6464 - val_loss: 1.5597 - val_acc: 0.5795
#
# Epoch 00009: val_acc did not improve from 0.59550
#  - lr: 0.04597 - momentum: 0.91
# Epoch 10/300
# 97/97 [==============================] - 33s 337ms/step - loss: 0.9311 - acc: 0.6671 - val_loss: 1.2223 - val_acc: 0.5836
#
# Epoch 00010: val_acc did not improve from 0.59550
#  - lr: 0.04997 - momentum: 0.91
# Epoch 11/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.9056 - acc: 0.6769 - val_loss: 1.0139 - val_acc: 0.6431
#
# Epoch 00011: val_acc improved from 0.59550 to 0.64310, saving model to Resnet-13.hdf5
#  - lr: 0.05397 - momentum: 0.90
# Epoch 12/300
# 97/97 [==============================] - 32s 335ms/step - loss: 0.8479 - acc: 0.6982 - val_loss: 0.9672 - val_acc: 0.6760
#
# Epoch 00012: val_acc improved from 0.64310 to 0.67600, saving model to Resnet-13.hdf5
#  - lr: 0.05797 - momentum: 0.90
# Epoch 13/300
# 97/97 [==============================] - 33s 336ms/step - loss: 0.8088 - acc: 0.7133 - val_loss: 1.2484 - val_acc: 0.6316
#
# Epoch 00013: val_acc did not improve from 0.67600
#  - lr: 0.06197 - momentum: 0.89
# Epoch 14/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.7884 - acc: 0.7224 - val_loss: 1.0585 - val_acc: 0.6718
#
# Epoch 00014: val_acc did not improve from 0.67600
#  - lr: 0.06597 - momentum: 0.89
# Epoch 15/300
# 97/97 [==============================] - 33s 336ms/step - loss: 0.7526 - acc: 0.7371 - val_loss: 0.7455 - val_acc: 0.7480
#
# Epoch 00015: val_acc improved from 0.67600 to 0.74800, saving model to Resnet-13.hdf5
#  - lr: 0.06997 - momentum: 0.88
# Epoch 16/300
# 97/97 [==============================] - 33s 335ms/step - loss: 0.7162 - acc: 0.7486 - val_loss: 0.7801 - val_acc: 0.7422
#
# Epoch 00016: val_acc did not improve from 0.74800
#  - lr: 0.07397 - momentum: 0.88
# Epoch 17/300
# 97/97 [==============================] - 32s 333ms/step - loss: 0.6826 - acc: 0.7623 - val_loss: 0.9273 - val_acc: 0.7205
#
# Epoch 00017: val_acc did not improve from 0.74800
#  - lr: 0.07797 - momentum: 0.87
# Epoch 18/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.6647 - acc: 0.7675 - val_loss: 0.8310 - val_acc: 0.7580
#
# Epoch 00018: val_acc improved from 0.74800 to 0.75800, saving model to Resnet-13.hdf5
#  - lr: 0.08198 - momentum: 0.87
# Epoch 19/300
# 97/97 [==============================] - 32s 335ms/step - loss: 0.6493 - acc: 0.7740 - val_loss: 0.6947 - val_acc: 0.7763
#
# Epoch 00019: val_acc improved from 0.75800 to 0.77630, saving model to Resnet-13.hdf5
#  - lr: 0.08598 - momentum: 0.87
# Epoch 20/300
# 97/97 [==============================] - 32s 333ms/step - loss: 0.6251 - acc: 0.7833 - val_loss: 0.6548 - val_acc: 0.7787
#
# Epoch 00020: val_acc improved from 0.77630 to 0.77870, saving model to Resnet-13.hdf5
#  - lr: 0.08998 - momentum: 0.86
# Epoch 21/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.5959 - acc: 0.7937 - val_loss: 0.5933 - val_acc: 0.8053
#
# Epoch 00021: val_acc improved from 0.77870 to 0.80530, saving model to Resnet-13.hdf5
#  - lr: 0.09398 - momentum: 0.86
# Epoch 22/300
# 97/97 [==============================] - 33s 336ms/step - loss: 0.5932 - acc: 0.7921 - val_loss: 0.7640 - val_acc: 0.7761
#
# Epoch 00022: val_acc did not improve from 0.80530
#  - lr: 0.09798 - momentum: 0.85
# Epoch 23/300
# 97/97 [==============================] - 32s 333ms/step - loss: 0.5646 - acc: 0.8044 - val_loss: 0.9636 - val_acc: 0.6936
#
# Epoch 00023: val_acc did not improve from 0.80530
#  - lr: 0.09802 - momentum: 0.85
# Epoch 24/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.5444 - acc: 0.8108 - val_loss: 1.1505 - val_acc: 0.6815
#
# Epoch 00024: val_acc did not improve from 0.80530
#  - lr: 0.09402 - momentum: 0.86
# Epoch 25/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.5226 - acc: 0.8175 - val_loss: 0.8103 - val_acc: 0.7432
#
# Epoch 00025: val_acc did not improve from 0.80530
#  - lr: 0.09002 - momentum: 0.86
# Epoch 26/300
# 97/97 [==============================] - 32s 333ms/step - loss: 0.5092 - acc: 0.8212 - val_loss: 0.5096 - val_acc: 0.8380
#
# Epoch 00026: val_acc improved from 0.80530 to 0.83800, saving model to Resnet-13.hdf5
#  - lr: 0.08602 - momentum: 0.87
# Epoch 27/300
# 97/97 [==============================] - 32s 333ms/step - loss: 0.4927 - acc: 0.8289 - val_loss: 0.6114 - val_acc: 0.8074
#
# Epoch 00027: val_acc did not improve from 0.83800
#  - lr: 0.08202 - momentum: 0.87
# Epoch 28/300
# 97/97 [==============================] - 32s 335ms/step - loss: 0.4909 - acc: 0.8323 - val_loss: 0.7988 - val_acc: 0.7649
#
# Epoch 00028: val_acc did not improve from 0.83800
#  - lr: 0.07802 - momentum: 0.87
# Epoch 29/300
# 97/97 [==============================] - 32s 333ms/step - loss: 0.4634 - acc: 0.8371 - val_loss: 0.5460 - val_acc: 0.8221
#
# Epoch 00029: val_acc did not improve from 0.83800
#  - lr: 0.07401 - momentum: 0.88
# Epoch 30/300
# 97/97 [==============================] - 32s 335ms/step - loss: 0.4567 - acc: 0.8418 - val_loss: 0.5554 - val_acc: 0.8249
#
# Epoch 00030: val_acc did not improve from 0.83800
#  - lr: 0.07001 - momentum: 0.88
# Epoch 31/300
# 97/97 [==============================] - 33s 335ms/step - loss: 0.4331 - acc: 0.8489 - val_loss: 0.4531 - val_acc: 0.8509
#
# Epoch 00031: val_acc improved from 0.83800 to 0.85090, saving model to Resnet-13.hdf5
#  - lr: 0.06601 - momentum: 0.89
# Epoch 32/300
# 97/97 [==============================] - 32s 335ms/step - loss: 0.4287 - acc: 0.8519 - val_loss: 0.4845 - val_acc: 0.8441
#
# Epoch 00032: val_acc did not improve from 0.85090
#  - lr: 0.06201 - momentum: 0.89
# Epoch 33/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.4208 - acc: 0.8530 - val_loss: 0.5520 - val_acc: 0.8324
#
# Epoch 00033: val_acc did not improve from 0.85090
#  - lr: 0.05801 - momentum: 0.90
# Epoch 34/300
# 97/97 [==============================] - 32s 335ms/step - loss: 0.4067 - acc: 0.8577 - val_loss: 0.5099 - val_acc: 0.8408
#
# Epoch 00034: val_acc did not improve from 0.85090
#  - lr: 0.05401 - momentum: 0.90
# Epoch 35/300
# 97/97 [==============================] - 32s 332ms/step - loss: 0.3995 - acc: 0.8609 - val_loss: 0.4577 - val_acc: 0.8476
#
# Epoch 00035: val_acc did not improve from 0.85090
#  - lr: 0.05001 - momentum: 0.91
# Epoch 36/300
# 97/97 [==============================] - 32s 335ms/step - loss: 0.3923 - acc: 0.8628 - val_loss: 0.5668 - val_acc: 0.8154
#
# Epoch 00036: val_acc did not improve from 0.85090
#  - lr: 0.04601 - momentum: 0.91
# Epoch 37/300
# 97/97 [==============================] - 32s 333ms/step - loss: 0.3754 - acc: 0.8713 - val_loss: 0.5448 - val_acc: 0.8330
#
# Epoch 00037: val_acc did not improve from 0.85090
#  - lr: 0.04201 - momentum: 0.91
# Epoch 38/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.3655 - acc: 0.8731 - val_loss: 0.3450 - val_acc: 0.8828
#
# Epoch 00038: val_acc improved from 0.85090 to 0.88280, saving model to Resnet-13.hdf5
#  - lr: 0.03801 - momentum: 0.92
# Epoch 39/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.3456 - acc: 0.8799 - val_loss: 0.5004 - val_acc: 0.8541
#
# Epoch 00039: val_acc did not improve from 0.88280
#  - lr: 0.03401 - momentum: 0.92
# Epoch 40/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.3537 - acc: 0.8765 - val_loss: 0.4073 - val_acc: 0.8770
#
# Epoch 00040: val_acc did not improve from 0.88280
#  - lr: 0.03000 - momentum: 0.93
# Epoch 41/300
# 97/97 [==============================] - 32s 333ms/step - loss: 0.3354 - acc: 0.8831 - val_loss: 0.3706 - val_acc: 0.8780
#
# Epoch 00041: val_acc did not improve from 0.88280
#  - lr: 0.02600 - momentum: 0.93
# Epoch 42/300
# 97/97 [==============================] - 32s 335ms/step - loss: 0.3248 - acc: 0.8848 - val_loss: 0.7460 - val_acc: 0.7975
#
# Epoch 00042: val_acc did not improve from 0.88280
#  - lr: 0.02200 - momentum: 0.94
# Epoch 43/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.3063 - acc: 0.8940 - val_loss: 0.4313 - val_acc: 0.8655
#
# Epoch 00043: val_acc did not improve from 0.88280
#  - lr: 0.01800 - momentum: 0.94
# Epoch 44/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.2998 - acc: 0.8956 - val_loss: 0.3449 - val_acc: 0.8932
#
# Epoch 00044: val_acc improved from 0.88280 to 0.89320, saving model to Resnet-13.hdf5
#  - lr: 0.01400 - momentum: 0.95
# Epoch 45/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.2927 - acc: 0.8972 - val_loss: 0.3227 - val_acc: 0.8990
#
# Epoch 00045: val_acc improved from 0.89320 to 0.89900, saving model to Resnet-13.hdf5
#  - lr: 0.01000 - momentum: 0.95
# Epoch 46/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.2723 - acc: 0.9036 - val_loss: 0.3251 - val_acc: 0.9008
#
# Epoch 00046: val_acc improved from 0.89900 to 0.90080, saving model to Resnet-13.hdf5
#  - lr: 0.00802 - momentum: 0.95
# Epoch 47/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.2612 - acc: 0.9074 - val_loss: 0.3203 - val_acc: 0.9006
#
# Epoch 00047: val_acc did not improve from 0.90080
#  - lr: 0.00605 - momentum: 0.95
# Epoch 48/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.2536 - acc: 0.9120 - val_loss: 0.2935 - val_acc: 0.9078
#
# Epoch 00048: val_acc improved from 0.90080 to 0.90780, saving model to Resnet-13.hdf5
#  - lr: 0.00407 - momentum: 0.95
# Epoch 49/300
# 97/97 [==============================] - 32s 333ms/step - loss: 0.2465 - acc: 0.9135 - val_loss: 0.2904 - val_acc: 0.9114
#
# Epoch 00049: val_acc improved from 0.90780 to 0.91140, saving model to Resnet-13.hdf5
#  - lr: 0.00210 - momentum: 0.95
# Epoch 50/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.2392 - acc: 0.9154 - val_loss: 0.2813 - val_acc: 0.9152
#
# Epoch 00050: val_acc improved from 0.91140 to 0.91520, saving model to Resnet-13.hdf5
#  - lr: 0.00012 - momentum: 0.95
# Epoch 51/300
# 97/97 [==============================] - 32s 333ms/step - loss: 0.2554 - acc: 0.9096 - val_loss: 0.3095 - val_acc: 0.9023
#
# Epoch 00051: val_acc did not improve from 0.91520
#  - lr: 0.01396 - momentum: 0.95
# Epoch 52/300
# 97/97 [==============================] - 32s 333ms/step - loss: 0.2715 - acc: 0.9029 - val_loss: 0.3428 - val_acc: 0.8951
#
# Epoch 00052: val_acc did not improve from 0.91520
#  - lr: 0.01796 - momentum: 0.94
# Epoch 53/300
# 97/97 [==============================] - 32s 333ms/step - loss: 0.2807 - acc: 0.9011 - val_loss: 0.3472 - val_acc: 0.8952
#
# Epoch 00053: val_acc did not improve from 0.91520
#  - lr: 0.02196 - momentum: 0.94
# Epoch 54/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.2899 - acc: 0.8985 - val_loss: 0.3737 - val_acc: 0.8821
#
# Epoch 00054: val_acc did not improve from 0.91520
#  - lr: 0.02596 - momentum: 0.93
# Epoch 55/300
# 97/97 [==============================] - 32s 333ms/step - loss: 0.2973 - acc: 0.8950 - val_loss: 0.3498 - val_acc: 0.8936
#
# Epoch 00055: val_acc did not improve from 0.91520
#  - lr: 0.02996 - momentum: 0.93
# Epoch 56/300
# 97/97 [==============================] - 32s 333ms/step - loss: 0.2935 - acc: 0.8980 - val_loss: 0.4223 - val_acc: 0.8762
#
# Epoch 00056: val_acc did not improve from 0.91520
#  - lr: 0.03396 - momentum: 0.92
# Epoch 57/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.2988 - acc: 0.8958 - val_loss: 0.4789 - val_acc: 0.8522
#
# Epoch 00057: val_acc did not improve from 0.91520
#  - lr: 0.03797 - momentum: 0.92
# Epoch 58/300
# 97/97 [==============================] - 32s 333ms/step - loss: 0.2925 - acc: 0.8978 - val_loss: 0.4708 - val_acc: 0.8682
#
# Epoch 00058: val_acc did not improve from 0.91520
#  - lr: 0.04197 - momentum: 0.91
# Epoch 59/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.3103 - acc: 0.8898 - val_loss: 0.6144 - val_acc: 0.8371
#
# Epoch 00059: val_acc did not improve from 0.91520
#  - lr: 0.04597 - momentum: 0.91
# Epoch 60/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.2969 - acc: 0.8954 - val_loss: 0.4617 - val_acc: 0.8723
#
# Epoch 00060: val_acc did not improve from 0.91520
#  - lr: 0.04997 - momentum: 0.91
# Epoch 61/300
# 97/97 [==============================] - 32s 333ms/step - loss: 0.3055 - acc: 0.8937 - val_loss: 0.4776 - val_acc: 0.8473
#
# Epoch 00061: val_acc did not improve from 0.91520
#  - lr: 0.05397 - momentum: 0.90
# Epoch 62/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.3002 - acc: 0.8944 - val_loss: 0.4739 - val_acc: 0.8697
#
# Epoch 00062: val_acc did not improve from 0.91520
#  - lr: 0.05797 - momentum: 0.90
# Epoch 63/300
# 97/97 [==============================] - 32s 334ms/step - loss: 0.3058 - acc: 0.8918 - val_loss: 0.3635 - val_acc: 0.8893
#
# Epoch 00063: val_acc did not improve from 0.91520
#  - lr: 0.06197 - momentum: 0.89
# Epoch 64/300
# 97/97 [==============================] - 32s 332ms/step - loss: 0.2937 - acc: 0.8956 - val_loss: 0.3717 - val_acc: 0.8869
#
# Epoch 00064: val_acc did not improve from 0.91520
#  - lr: 0.06597 - momentum: 0.89
# Epoch 65/300
# 97/97 [==============================] - 33s 335ms/step - loss: 0.2965 - acc: 0.8968 - val_loss: 0.4235 - val_acc: 0.8774
#
# Epoch 00065: val_acc did not improve from 0.91520
#  - lr: 0.06997 - momentum: 0.88
# Epoch 66/300
# 89/97 [==========================>...] - ETA: 2s - loss: 0.2993 - acc: 0.8955
